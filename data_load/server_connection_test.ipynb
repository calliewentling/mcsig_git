# %% [markdown]
# # TEST for Entradas

# %%
import pandas as pd
import geopandas as gpd
import geojson
import psycopg2
import os

# change the current working directory 
# to specified path
os.chdir(r'c:\\mcsig_git\data_load')
  
# varify the path using getcwd()
cwd = os.getcwd()
  
# print the current directory
print("Current working directory is:", cwd)

conn = psycopg2.connect("host=localhost dbname=postgres user=postgres password=thesis2021")
cur = conn.cursor()
print("connected!")

cur.execute(''' SELECT * FROM apregoar_test.entrada_test ''')
entradaEntries = cur.fetchall()
print("Entradas loaded")
print()
print(entradaEntries)
print()
df = pd.DataFrame(data=entradaEntries)
print(df)
print()


#entradaEntries["tEnd"] = rawStories['tEnd'].dt.strftime("%x")
#print("Unassigned datetime to pandas df, because GEOJSON doesn't like it")
#print()
#print(entradaEntries)
df.columns = ['authorName', 'entradaId', 'placeDesc', 'placeName', 'publishDate', 'sectionName', 'stypeName', 'summary', 'tBegin', 'tDesc', 'tEnd', 'themeName', 'title', 'webLink', 'publisherName']
df.info()
df["publishDate"] = pd.to_datetime(df['publishDate']) #https://strftime.org/
df["tBegin"] = df['tBegin'].astype('datetime64')
df["tEnd"] = df['tEnd'].astype('datetime64')
df.info()
print(df)
data = df.to_json(r'C:\mcsig_git\Apregoar\app\store\entradaEntries.json', orient='records')
print()
print("Data is: ")
print(data)
#rawStories.to_json()
# Out:
# Current working directory is: c:\mcsig_git\data_load
# connected!
# Entradas loaded
#
# [('Callie', 1, 'Place Description Test\n', 'Place name test', datetime.date(2021, 10, 8), 'Section Test', 'Type Test', 'A brief summary test', datetime.date(2021, 1, 1), 'One day event', datetime.date(2021, 2, 1), 'Theme Test\n', 'Title test', 'http://amensagem.pt', 'Publisher test'), ('Wentling', 2, 'Test2', 'Test2', datetime.date(2021, 8, 11), 'test2', 'test2', 'test2', datetime.date(2021, 8, 1), 'Week', datetime.date(2021, 8, 7), 'Test2', 'Test2', 'Test2', 'Test2'), ('Bernardo', 3, 'Test3?', 'Test2', datetime.date(2021, 8, 11), 'Test2', 'Test2', 'Test2', datetime.date(2021, 8, 1), 'Test2', datetime.date(2021, 8, 6), 'Test2', 'Test2', 'Test2', 'Test2')]
#
#          0   1                         2                3           4   \
# 0    Callie   1  Place Description Test\n  Place name test  2021-10-08
# 1  Wentling   2                     Test2            Test2  2021-08-11
# 2  Bernardo   3                    Test3?            Test2  2021-08-11
#
#              5          6                     7           8              9   \
# 0  Section Test  Type Test  A brief summary test  2021-01-01  One day event
# 1         test2      test2                 test2  2021-08-01           Week
# 2         Test2      Test2                 Test2  2021-08-01          Test2
#
#            10            11          12                   13              14
# 0  2021-02-01  Theme Test\n  Title test  http://amensagem.pt  Publisher test
# 1  2021-08-07         Test2       Test2                Test2           Test2
# 2  2021-08-06         Test2       Test2                Test2           Test2
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   authorName     3 non-null      object
#  1   entradaId      3 non-null      int64
#  2   placeDesc      3 non-null      object
#  3   placeName      3 non-null      object
#  4   publishDate    3 non-null      object
#  5   sectionName    3 non-null      object
#  6   stypeName      3 non-null      object
#  7   summary        3 non-null      object
#  8   tBegin         3 non-null      object
#  9   tDesc          3 non-null      object
#  10  tEnd           3 non-null      object
#  11  themeName      3 non-null      object
#  12  title          3 non-null      object
#  13  webLink        3 non-null      object
#  14  publisherName  3 non-null      object
# dtypes: int64(1), object(14)
# memory usage: 488.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   authorName     3 non-null      object
#  1   entradaId      3 non-null      int64
#  2   placeDesc      3 non-null      object
#  3   placeName      3 non-null      object
#  4   publishDate    3 non-null      datetime64[ns]
#  5   sectionName    3 non-null      object
#  6   stypeName      3 non-null      object
#  7   summary        3 non-null      object
#  8   tBegin         3 non-null      datetime64[ns]
#  9   tDesc          3 non-null      object
#  10  tEnd           3 non-null      datetime64[ns]
#  11  themeName      3 non-null      object
#  12  title          3 non-null      object
#  13  webLink        3 non-null      object
#  14  publisherName  3 non-null      object
# dtypes: datetime64[ns](3), int64(1), object(11)
# memory usage: 488.0+ bytes
#   authorName  entradaId                 placeDesc        placeName  \
# 0     Callie          1  Place Description Test\n  Place name test
# 1   Wentling          2                     Test2            Test2
# 2   Bernardo          3                    Test3?            Test2
#
#   publishDate   sectionName  stypeName               summary     tBegin  \
# 0  2021-10-08  Section Test  Type Test  A brief summary test 2021-01-01
# 1  2021-08-11         test2      test2                 test2 2021-08-01
# 2  2021-08-11         Test2      Test2                 Test2 2021-08-01
#
#            tDesc       tEnd     themeName       title              webLink  \
# 0  One day event 2021-02-01  Theme Test\n  Title test  http://amensagem.pt
# 1           Week 2021-08-07         Test2       Test2                Test2
# 2          Test2 2021-08-06         Test2       Test2                Test2
#
#     publisherName
# 0  Publisher test
# 1           Test2
# 2           Test2
#
# Data is:
# None
